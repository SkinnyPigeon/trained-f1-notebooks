# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt
import warnings
from PIL import Image
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import label_map_util
import cv2

warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Model and Labels

# %%
label_path = os.path.join("models", "label_map.pbtxt")
model_path = os.path.join("models", "saved_model")

# %%
model = tf.saved_model.load(str(model_path))
model
# Out:
# <tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject at 0x2bcb874c0>

# %% [markdown]
# # Creating Label Map

# %%
def create_category_index(label_path):
    category_index = label_map_util.create_categories_from_labelmap(str(label_path), use_display_name=True)
    cat_dict = {}
    for i, cat in enumerate(category_index):
        cat_dict[i+ 1] = cat
    return cat_dict

# %%
category_index = create_category_index(label_path)
category_index
# Out:
# {1: {'id': 1, 'name': 'alpha-romeo'},
#  2: {'id': 2, 'name': 'alpha-tauri'},
#  3: {'id': 3, 'name': 'alpine'},
#  4: {'id': 4, 'name': 'aston-martin'},
#  5: {'id': 5, 'name': 'ferrari'},
#  6: {'id': 6, 'name': 'haas'},
#  7: {'id': 7, 'name': 'mclaren'},
#  8: {'id': 8, 'name': 'mercedes'},
#  9: {'id': 9, 'name': 'red-bull'},
#  10: {'id': 10, 'name': 'williams'}}

# %% [markdown]
# # Object Detection

# %%
def load_image_into_numpy_array(path):
    return np.array(Image.open(path))

# %%
def run_inference_for_single_image(model, image):
    image = np.asarray(image)
    input_tensor = tf.convert_to_tensor(image)
    input_tensor = input_tensor[tf.newaxis,...]
    model_fn = model.signatures['serving_default']
    output_dict = model_fn(input_tensor)

    num_detections = int(output_dict.pop('num_detections'))
    output_dict = {key:value[0, :num_detections].numpy() 
                 for key,value in output_dict.items()}
    
    output_dict['num_detections'] = num_detections
    output_dict['detection_classes'] = output_dict['detection_classes'].astype(np.int64)
   
    if 'detection_masks' in output_dict:
        detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
              output_dict['detection_masks'], output_dict['detection_boxes'],
               image.shape[0], image.shape[1])      
        detection_masks_reframed = tf.cast(detection_masks_reframed > 0.5,
                                       tf.uint8)
        output_dict['detection_masks_reframed'] = detection_masks_reframed.numpy()
    
    return output_dict

# %%
def apply_inference(model, image):
    image_np = np.array(image)
    output_dict = run_inference_for_single_image(model, image_np)
    viz_utils.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks_reframed', None),
        use_normalized_coordinates=True,
        line_thickness=2,
        max_boxes_to_draw=20,
        min_score_thresh=0.1)

    return image_np

# %%
image_path = os.path.join("images_v1", "check.jpg")
res = apply_inference(model, Image.open(image_path))
display(Image.fromarray(res))
# Out:
# <PIL.Image.Image image mode=RGB size=2858x1474>

# %% [markdown]
# # Applying Object Detection To Video

# %%
def detect_video(input_path, output_path, model):
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    out = cv2.VideoWriter(output_path, fourcc, 25.0, (854, 480))
    vidcap = cv2.VideoCapture(input_path)
    length = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_read, image = vidcap.read()
    count = 0
    while frame_read:
        output_file = apply_inference(model, image)
        out.write(output_file)
        frame_read, image = vidcap.read()
        count += 1
        if count % 100 == 0:
            print(f"Completed: {(count/length) * 100:.2f}%")
    vidcap.release()
    out.release()
    print("Completed: 100%")

# %%
input_path = os.path.join("video_v1", "canada.mp4")
output_path = os.path.join("video_v1", "output-full.mp4")

# %%
detect_video(input_path, output_path, model)
# Out:
# Completed: 0.92%
# Completed: 1.85%
# Completed: 2.77%
# Completed: 3.69%
# Completed: 4.62%
# Completed: 5.54%
# Completed: 6.46%
# Completed: 7.39%
# Completed: 8.31%
# Completed: 9.23%
# Completed: 10.16%
# Completed: 11.08%
# Completed: 12.00%
# Completed: 12.93%
# Completed: 13.85%
# Completed: 14.77%
# Completed: 15.70%
# Completed: 16.62%
# Completed: 17.54%
# Completed: 18.47%
# Completed: 19.39%
# Completed: 20.31%
# Completed: 21.24%
# Completed: 22.16%
# Completed: 23.08%
# Completed: 24.01%
# Completed: 24.93%
# Completed: 25.85%
# Completed: 26.78%
# Completed: 27.70%
# Completed: 28.62%
# Completed: 29.55%
# Completed: 30.47%
# Completed: 31.39%
# Completed: 32.32%
# Completed: 33.24%
# Completed: 34.16%
# Completed: 35.09%
# Completed: 36.01%
# Completed: 36.93%
# Completed: 37.86%
# Completed: 38.78%
# Completed: 39.70%
# Completed: 40.63%
# Completed: 41.55%
# Completed: 42.47%
# Completed: 43.40%
# Completed: 44.32%
# Completed: 45.24%
# Completed: 46.17%
# Completed: 47.09%
# Completed: 48.01%
# Completed: 48.94%
# Completed: 49.86%
# Completed: 50.78%
# Completed: 51.71%
# Completed: 52.63%
# Completed: 53.55%
# Completed: 54.48%
# Completed: 55.40%
# Completed: 56.33%
# Completed: 57.25%
# Completed: 58.17%
# Completed: 59.10%
# Completed: 60.02%
# Completed: 60.94%
# Completed: 61.87%
# Completed: 62.79%
# Completed: 63.71%
# Completed: 64.64%
# Completed: 65.56%
# Completed: 66.48%
# Completed: 67.41%
# Completed: 68.33%
# Completed: 69.25%
# Completed: 70.18%
# Completed: 71.10%
# Completed: 72.02%
# Completed: 72.95%
# Completed: 73.87%
# Completed: 74.79%
# Completed: 75.72%
# Completed: 76.64%
# Completed: 77.56%
# Completed: 78.49%
# Completed: 79.41%
# Completed: 80.33%
# Completed: 81.26%
# Completed: 82.18%
# Completed: 83.10%
# Completed: 84.03%
# Completed: 84.95%
# Completed: 85.87%
# Completed: 86.80%
# Completed: 87.72%
# Completed: 88.64%
# Completed: 89.57%
# Completed: 90.49%
# Completed: 91.41%
# Completed: 92.34%
# Completed: 93.26%
# Completed: 94.18%
# Completed: 95.11%
# Completed: 96.03%
# Completed: 96.95%
# Completed: 97.88%
# Completed: 98.80%
# Completed: 99.72%
# Completed: 100%
